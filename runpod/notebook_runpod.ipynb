# %% [markdown]
# # scenario-reasoner-lm RunPod DPO Training

# %%
import subprocess, sys
from pathlib import Path
repo = Path.cwd()
subprocess.run(["bash", "runpod/setup.sh"], cwd=repo, check=True)
subprocess.run([sys.executable, "runpod/train.py"], cwd=repo, check=True)
